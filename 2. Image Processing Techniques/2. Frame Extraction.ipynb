# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('rgb.jpeg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
r = img[ : , : , 0]  # - Red
g = img[ : , : , 1]  # - Green
b = img[ : , : , 2]  # - Blue

# %%
plt.imshow(g)

# %%
plt.imshow(r)

# %%
plt.imshow(b)

# %%
plt.imshow(img[120:300  , 120:290 , : ])

# %%
img = cv.imread('Transition.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img.shape
# Out:
# (1536, 1536, 3)

# %%
r = img[ : , : , 0 ]
g = img[ : , : , 1 ]
b = img[ : , : , 2 ]
